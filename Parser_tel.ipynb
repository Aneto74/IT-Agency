# %%
#Пример Google Sheet который конвертнул в csv: https://docs.google.com/spreadsheets/d/1ixw5YIfXPwAJyse1WAg00vYDjd6wwT3_KG8PFrpBaQ8/edit#gid=0
#Это первый шаг, делать его обазетельно

from bs4 import BeautifulSoup
#from fake_useragent import UserAgent -- если нужно проверять с мобилы
import pandas as pd
import requests
import warnings; warnings.simplefilter('ignore') #убираем предупреждения
import re

#ua = UserAgent()

df = pd.read_csv('url_cmrt.ru.csv')

df['tel'] = df['tel'].astype('str')

for i in range(len(df)):
    if 'http://' not in df.iloc[i, 0]:
        df.iloc[i, 0] = 'http://' + df.iloc[i, 0]
        
    if len(df.loc[i, 'tel']) == 11:
        df.loc[i, 'tel'] = '+' + str(df.loc[i, 'tel'])
    elif len(df.loc[i, 'tel']) == 10:
        df.loc[i, 'tel'] = '+7' + str(df.loc[i, 'tel'])
        
    url = df.loc[i, 'Url']
    soup = BeautifulSoup(requests.get(url, headers={'Cache-Control': 'no-cache'}).text)
    links = soup.find_all('a', href=re.compile("tel:"))
    
    link_temporary = []
    
    for link in links:
        l = link['href']
        link_temporary.append(l[4:])
    
    for b in range(len(link_temporary)):
        for a in link_temporary:
            here = 'tel-' + str(b)
            df.loc[i, here] = a
            df[here] = df[here].astype('str')
    
            if len(df.loc[i, here]) > 12:
                df.loc[i, here] = df.loc[i, here].replace(" ", "")        
                df.loc[i, here] = df.loc[i, here].replace("\u200b", "")
            df.loc[i, 'NoError-' + here] = (df.loc[i, 'tel'] == df.loc[i, here])

df.to_csv('cmrt-out.csv', sep=',')

df
# Out:
#                                                   Url           tel  \
# 0   http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74951819601
# 1   http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74951819602
# 2   http://mydiagnost.ru/?utm_source=google&utm_me...  +74951819603
# 3              http://cmrt365.ru/?utm_source=referral  +74981819605
# 4   http://spb.cmrt365.ru/?utm_source=yandex&utm_m...  +78126400247
# 5   http://spb.cmrt365.ru/?utm_source=yandex&utm_m...  +78126400249
# 6   http://spb.mydiagnost.ru/?utm_source=google&ut...  +78126400269
# 7           http://spb.cmrt365.ru/?utm_source=organic  +78126400279
# 8          http://spb.cmrt365.ru/?utm_source=referral  +78126400284
# 9   http://vng.cmrt365.ru/?utm_source=yandex&utm_m...  +78162280803
# 10  http://vng.cmrt365.ru/?utm_source=yandex&utm_m...  +78162280803
# 11  http://vng.mydiagnost.ru/?utm_source=google&ut...  +78162280803
# 12          http://vng.cmrt365.ru/?utm_source=organic  +78162280803
# 13         http://vng.cmrt365.ru/?utm_source=referral  +78162280803
# 14  http://spb.cmrt365.ru/?utm_source=mt&utm_mediu...  +78126400371
# 15  http://spb.cmrt365.ru/?utm_source=vk&utm_mediu...  +78126400372
# 16  http://spb.cmrt365.ru/?utm_source=yandex&utm_m...  +78126400981
# 17  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74959819606
# 18  http://spb.cmrt365.ru/?utm_source=yandex&utm_m...  +78126403681
# 19  http://spb.cmrt365.ru/?utm_source=yandex&utm_m...  +78126403678
# 20  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74951819628
# 21  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74951819609
# 22  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74956403610
# 23  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74956403611
# 24  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74956403612
# 25  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74951819607
# 26  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74951819621
# 27  http://spb.cmrt365.ru/?utm_source=soloway&utm_...  +78126403679
# 28  http://cmrt365.ru/?utm_source=soloway&utm_medi...  +74951819608
#
#            tel-0 NoError-tel-0         tel-1 NoError-tel-1         tel-2  \
# 0   +74951819601          True  +74951819601          True  +74951819601
# 1   +74951819602          True  +74951819602          True  +74951819602
# 2   +74951819603          True  +74951819603          True  +74951819603
# 3   +74951819605         False  +74951819605         False  +74951819605
# 4   +78126400247          True  +78126400247          True  +78126400247
# 5   +78126400249          True  +78126400249          True  +78126400249
# 6   +78126400269          True  +78126400269          True  +78126400269
# 7   +78126400279          True  +78126400279          True  +78126400279
# 8   +78126400284          True  +78126400284          True  +78126400284
# 9   +78162280803          True  +78162280803          True  +78162280803
# 10  +78162280803          True  +78162280803          True  +78162280803
# 11  +78162280803          True  +78162280803          True  +78162280803
# 12  +78162280803          True  +78162280803          True  +78162280803
# 13  +78162280803          True  +78162280803          True  +78162280803
# 14  +78126400371          True  +78126400371          True  +78126400371
# 15  +78126400372          True  +78126400372          True  +78126400372
# 16  +78126400981          True  +78126400981          True  +78126400981
# 17  +74951819606         False  +74951819606         False  +74951819606
# 18  +78126403681          True  +78126403681          True  +78126403681
# 19  +78126403678          True  +78126403678          True  +78126403678
# 20  +74951819628          True  +74951819628          True  +74951819628
# 21  +74951819609          True  +74951819609          True  +74951819609
# 22  +74956403610          True  +74956403610          True  +74956403610
# 23  +74956403611          True  +74956403611          True  +74956403611
# 24  +74956403612          True  +74956403612          True  +74956403612
# 25  +74951819607          True  +74951819607          True  +74951819607
# 26  +74951819621          True  +74951819621          True  +74951819621
# 27  +78126403679          True  +78126403679          True  +78126403679
# 28  +74951819608          True  +74951819608          True  +74951819608
#
#    NoError-tel-2         tel-3 NoError-tel-3         tel-4 NoError-tel-4  \
# 0           True  +74951819601          True  +74951819601          True
# 1           True  +74951819602          True  +74951819602          True
# 2           True  +74951819603          True  +74951819603          True
# 3          False  +74951819605         False  +74951819605         False
# 4           True  +78126400247          True  +78126400247          True
# 5           True  +78126400249          True  +78126400249          True
# 6           True  +78126400269          True  +78126400269          True
# 7           True  +78126400279          True  +78126400279          True
# 8           True  +78126400284          True  +78126400284          True
# 9           True  +78162280803          True  +78162280803          True
# 10          True  +78162280803          True  +78162280803          True
# 11          True  +78162280803          True  +78162280803          True
# 12          True  +78162280803          True  +78162280803          True
# 13          True  +78162280803          True  +78162280803          True
# 14          True  +78126400371          True  +78126400371          True
# 15          True  +78126400372          True  +78126400372          True
# 16          True  +78126400981          True  +78126400981          True
# 17         False  +74951819606         False  +74951819606         False
# 18          True  +78126403681          True  +78126403681          True
# 19          True  +78126403678          True  +78126403678          True
# 20          True  +74951819628          True  +74951819628          True
# 21          True  +74951819609          True  +74951819609          True
# 22          True  +74956403610          True  +74956403610          True
# 23          True  +74956403611          True  +74956403611          True
# 24          True  +74956403612          True  +74956403612          True
# 25          True  +74951819607          True  +74951819607          True
# 26          True  +74951819621          True  +74951819621          True
# 27          True  +78126403679          True  +78126403679          True
# 28          True  +74951819608          True  +74951819608          True
#
#            tel-5 NoError-tel-5         tel-6 NoError-tel-6         tel-7  \
# 0   +74951819601          True  +74951819601          True  +74951819601
# 1   +74951819602          True  +74951819602          True  +74951819602
# 2   +74951819603          True  +74951819603          True  +74951819603
# 3   +74951819605         False  +74951819605         False  +74951819605
# 4   +78126400247          True  +78126400247          True  +78126400247
# 5   +78126400249          True  +78126400249          True  +78126400249
# 6   +78126400269          True  +78126400269          True  +78126400269
# 7   +78126400279          True  +78126400279          True  +78126400279
# 8   +78126400284          True  +78126400284          True  +78126400284
# 9   +78162280803          True  +78162280803          True  +78162280803
# 10  +78162280803          True  +78162280803          True  +78162280803
# 11  +78162280803          True  +78162280803          True  +78162280803
# 12  +78162280803          True  +78162280803          True  +78162280803
# 13  +78162280803          True  +78162280803          True  +78162280803
# 14  +78126400371          True  +78126400371          True  +78126400371
# 15  +78126400372          True  +78126400372          True  +78126400372
# 16  +78126400981          True  +78126400981          True  +78126400981
# 17  +74951819606         False  +74951819606         False  +74951819606
# 18  +78126403681          True  +78126403681          True  +78126403681
# 19  +78126403678          True  +78126403678          True  +78126403678
# 20  +74951819628          True  +74951819628          True  +74951819628
# 21  +74951819609          True  +74951819609          True  +74951819609
# 22  +74956403610          True  +74956403610          True  +74956403610
# 23  +74956403611          True  +74956403611          True  +74956403611
# 24  +74956403612          True  +74956403612          True  +74956403612
# 25  +74951819607          True  +74951819607          True  +74951819607
# 26  +74951819621          True  +74951819621          True  +74951819621
# 27  +78126403679          True  +78126403679          True  +78126403679
# 28  +74951819608          True  +74951819608          True  +74951819608
#
#    NoError-tel-7
# 0           True
# 1           True
# 2           True
# 3          False
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11          True
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17         False
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27          True
# 28          True

# %%
# Второй шаг — показывает только значения где есть ошибки. Первый шаг сделать обязательно.

df_column = df.columns.get_values()
df_column.tolist()
column_result = [s for s in df_lll if 'NoError-tel' in s]

list_errors = []

for x in column_result:
    df_temp = df.loc[~df[x].isin([True])].index.values.tolist()
    for y in df_temp:
        list_errors.append(y)
    
output = []
for x in list_errors:
    if x not in output:
        output.append(x)

if len(output) == 0:
    print('Ошибок нет')
else:
    print('Ошибки находятся в строках: ' + str(output))
    display(df.loc[df.index.isin(output)])
# Out:
# Ошибки находятся в строках: [3, 17]
#                                                   Url           tel  \
# 3              http://cmrt365.ru/?utm_source=referral  +74981819605
# 17  http://cmrt365.ru/?utm_source=yandex&utm_mediu...  +74959819606
#
#            tel-0 NoError-tel-0         tel-1 NoError-tel-1         tel-2  \
# 3   +74951819605         False  +74951819605         False  +74951819605
# 17  +74951819606         False  +74951819606         False  +74951819606
#
#    NoError-tel-2         tel-3 NoError-tel-3         tel-4 NoError-tel-4  \
# 3          False  +74951819605         False  +74951819605         False
# 17         False  +74951819606         False  +74951819606         False
#
#            tel-5 NoError-tel-5         tel-6 NoError-tel-6         tel-7  \
# 3   +74951819605         False  +74951819605         False  +74951819605
# 17  +74951819606         False  +74951819606         False  +74951819606
#
#    NoError-tel-7  Falses
# 3          False     0.0
# 17         False     0.0
